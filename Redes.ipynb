# %%
#
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#
df = pd.read_excel('/content/Encuesta redes  (Respuestas).xlsx')
#
df.head(10)
#
#print(df.dtypes)
#
#print(df.isnull().sum())
# Out:
#            Marca temporal  Edad\n    Sexo             Ocupacion  \
# 0 2025-10-15 16:03:49.133      22  Hombre            Estudiante
# 1 2025-10-15 16:05:10.010      21  Hombre            Estudiante
# 2 2025-10-15 16:09:42.230      22   Mujer           Desempleado
# 3 2025-10-15 16:09:42.858      25   Mujer  Profesional/empleado
# 4 2025-10-15 16:10:11.508      15  Hombre            Estudiante
# 5 2025-10-15 16:11:37.135      20   Mujer            Estudiante
# 6 2025-10-15 16:12:44.738      22   Mujer            Estudiante
# 7 2025-10-15 16:14:10.145      22   Mujer            Estudiante
# 8 2025-10-15 16:15:48.417      22   Mujer  Profesional/empleado
# 9 2025-10-15 16:15:56.686      24  Hombre           Desempleado
#
#                Redes habituales Tiempo en redes  Momento del dia   \
# 0            Instagram, TIk tok       4-6 horas             Noche
# 1            Instagram, TIk tok  Más de 6 horas  Noche, Madrugada
# 2            Instagram, TIk tok       1-3 horas             Noche
# 3                     Instagram       1-3 horas             Noche
# 4            Instagram, TIk tok       4-6 horas      Tarde, Noche
# 5  Instagram, Facebook, TIk tok       4-6 horas  Noche, Madrugada
# 6            Instagram, TIk tok       4-6 horas  Noche, Madrugada
# 7           Instagram, Facebook       4-6 horas             Noche
# 8            Instagram, TIk tok       4-6 horas     Mañana, Tarde
# 9           Instagram, Facebook       1-3 horas            Mañana
#
#                                   Tipo de contenidos  \
# 0  La variedad de videos cortos y reels, Los chal...
# 1  La variedad de videos cortos y reels, Humor y ...
# 2  La variedad de videos cortos y reels, Humor y ...
# 3                      Deporte y actividades físicas
# 4  La variedad de videos cortos y reels, Los chal...
# 5  La variedad de videos cortos y reels, Música y...
# 6  Los challenges y trends, Música y bailes, Infl...
# 7  La variedad de videos cortos y reels, Influenc...
# 8  La variedad de videos cortos y reels, Influenc...
# 9  La variedad de videos cortos y reels, Deporte ...
#
#                                         Uso de redes Afectan tu vida diaria   \
# 0  Pasar el rato o entretenerme, Seguir trends y ...                      No
# 1  Pasar el rato o entretenerme, Comprar o ver pr...                 Tal vez
# 2                       Pasar el rato o entretenerme                 Tal vez
# 3  Charlar con amigos y/o familia, Aprender algo ...                      Sí
# 4  Pasar el rato o entretenerme, Charlar con amig...                      Sí
# 5  Pasar el rato o entretenerme, Charlar con amig...                      Sí
# 6  Pasar el rato o entretenerme, Comprar o ver pr...                      No
# 7  Pasar el rato o entretenerme, Charlar con amig...                      No
# 8  Pasar el rato o entretenerme, Charlar con amig...                 Tal vez
# 9  Pasar el rato o entretenerme, Comprar o ver pr...                      Sí
#
#    Bienestar  Productividad Impacto en relaciones  \
# 0          1              3                    Sí
# 1          3              3                    Sí
# 2          2              4               Tal vez
# 3          2              4                    Sí
# 4          2              4                    Sí
# 5          3              3               Tal vez
# 6          2              5                    Sí
# 7          1              5               Tal vez
# 8          2              3                    No
# 9          2              3                    No
#
#                             Influencia en relaciones beneficio de redes  \
# 0       Me ayudan a conectar más con otras personas.                 No
# 1       Me ayudan a conectar más con otras personas.                 Sí
# 2  Tienen una mezcla de efectos positivos y negat...                 Sí
# 3        No generan ningún cambio en mis relaciones.                 Sí
# 4  Me ayudan a conectar más con otras personas., ...            Tal vez
# 5       Me ayudan a conectar más con otras personas.                 No
# 6  Me ayudan a conectar más con otras personas., ...                 Sí
# 7       Me ayudan a conectar más con otras personas.                 Sí
# 8  Tienen una mezcla de efectos positivos y negat...                 Sí
# 9       Me alejan de las interacciones presenciales.                 No
#
#                                Porque es beneficioso  \
# 0              Informativo, Inspiración y motivación
# 1                                    Entretenimiento
# 2                       Informativo, Entretenimiento
# 3                                        Informativo
# 4  Informativo, Inspiración y motivación, Entrete...
# 5                                                NaN
# 6  Inspiración y motivación, Conexión con comunid...
# 7          Inspiración y motivación, Entretenimiento
# 8  Informativo, Inspiración y motivación, Entrete...
# 9                                                NaN
#
#                          Efectos negativos Datos personales
# 0                                      NaN             Nada
# 1                                      NaN             Poco
# 2                                      NaN             Poco
# 3                                      NaN             Nada
# 4            Sensacion de perder el tiempo             Nada
# 5  Ansiedad, Sensacion de perder el tiempo            Mucho
# 6                                      NaN             Poco
# 7                                      NaN     No lo pienso
# 8                                      NaN             Poco
# 9  Adicción, Sensacion de perder el tiempo     No lo pienso

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import spearmanr
import os

if not os.path.exists('graficos'):
    os.makedirs('graficos')

plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
# %matplotlib inline

df = pd.read_excel('/content/Encuesta redes  (Respuestas).xlsx')

df.columns = ['Marca temporal', 'Edad', 'Sexo', 'Ocupacion', 'Redes habituales',
              'Tiempo en redes', 'Momento del dia', 'Tipo de contenidos', 'Uso de redes',
              'Afectan tu vida diaria', 'Bienestar', 'Productividad', 'Impacto en relaciones',
              'Influencia en relaciones', 'beneficio de redes', 'Porque es beneficioso',
              'Efectos negativos', 'Datos personales']

df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
redes = df['Redes habituales'].str.split(', ').explode()
conteo = redes.value_counts()

plt.figure(figsize=(10,6))
bars = plt.barh(conteo.index, conteo.values, color='#1DA1F2')
plt.title('Redes sociales más utilizadas (n=34)', fontsize=16, fontweight='bold')
plt.xlabel('Número de usuarios')
plt.ylabel('Red social')
plt.gca().invert_yaxis()
for i, bar in enumerate(bars):
    plt.text(bar.get_width() + 0.4, bar.get_y() + bar.get_height()/2,
             str(conteo.values[i]), va='center', fontweight='bold', fontsize=12, color='white')
plt.tight_layout()
plt.savefig('graficos/redes_mas_usadas.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()

# %%
orden = ['1-3 horas', '4-6 horas', 'Más de 6 horas']
df['Tiempo en redes'] = pd.Categorical(df['Tiempo en redes'], categories=orden, ordered=True)
conteo_tiempo = df['Tiempo en redes'].value_counts().sort_index()

plt.figure(figsize=(9,6))
bars = plt.bar(conteo_tiempo.index, conteo_tiempo.values,
               color=['#66c2a5', '#fc8d62', '#e78ac3'], edgecolor='black', linewidth=1.5)
plt.title('Tiempo diario dedicado a redes sociales', fontsize=16, fontweight='bold')
plt.ylabel('Número de personas')
plt.xlabel('Horas por día')
for bar in bars:
    plt.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 0.4,
             f'{int(bar.get_height())}', ha='center', va='bottom', fontweight='bold', fontsize=12)
plt.tight_layout()
plt.savefig('graficos/tiempo_diario.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()

# %%
df['Bienestar_num'] = df['Bienestar'].astype(int)
df['Productividad_num'] = df['Productividad'].astype(int)

fig, axes = plt.subplots(1, 2, figsize=(16,6))
sns.boxplot(data=df, x='Tiempo en redes', y='Bienestar_num', ax=axes[0], palette="Reds")
axes[0].set_title('Impacto en bienestar emocional', fontweight='bold', fontsize=14)
axes[0].set_ylabel('Impacto negativo (1=Nada → 5=Mucho)')

sns.boxplot(data=df, x='Tiempo en redes', y='Productividad_num', ax=axes[1], palette="Blues")
axes[1].set_title('Impacto en productividad', fontweight='bold', fontsize=14)
axes[1].set_ylabel('Impacto negativo (1=Nada → 5=Mucho)')

plt.tight_layout()
plt.savefig('graficos/bienestar_productividad.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
# Out:
# /tmp/ipython-input-2263652201.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Tiempo en redes', y='Bienestar_num', ax=axes[0], palette="Reds")
# /tmp/ipython-input-2263652201.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Tiempo en redes', y='Productividad_num', ax=axes[1], palette="Blues")

# %%
plt.figure(figsize=(12,7))
sns.countplot(data=df, x='Influencia en relaciones', hue='Sexo', palette='Set2')
plt.title('¿Cómo influyen las redes en tus relaciones interpersonales?', fontsize=16, fontweight='bold')
plt.xlabel('')
plt.ylabel('Número de personas')
plt.legend(title='Sexo')
plt.xticks(rotation=20)
plt.tight_layout()
plt.savefig('graficos/influencia_relaciones.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()

# %%
df['madrugada'] = df['Momento del dia'].str.contains('Madrugada', case=False, na=False)
df['dependencia'] = (
    (df['Tiempo en redes'] == 'Más de 6 horas') |
    (df['madrugada'] == True) |
    (df['Afectan tu vida diaria'] == 'Sí')
)

total_dep = df['dependencia'].sum()
porc_dep = total_dep / len(df) * 100

plt.figure(figsize=(10,6))
sns.countplot(data=df, x='dependencia', hue='Ocupacion', palette='magma')
plt.title('Señales de posible dependencia (n=34)', fontsize=16, fontweight='bold')
plt.xlabel('¿Presenta señales de dependencia?')
plt.ylabel('Número de personas')
plt.legend(title='Ocupación')
plt.text(0.5, 16, f"{total_dep} de 34\n({porc_dep:.1f}%)", fontsize=16, fontweight='bold',
         ha='center', bbox=dict(boxstyle="round", facecolor="yellow", alpha=0.8))
plt.tight_layout()
plt.savefig('graficos/dependencia.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Edad', y='Bienestar_num', hue='Sexo', size='Productividad_num',
                sizes=(50,300), alpha=0.8, palette='dark')
plt.title('Edad vs Impacto en bienestar y productividad', fontsize=16, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.savefig('graficos/edad_impacto.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
